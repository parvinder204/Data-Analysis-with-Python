# %%
import numpy as np

# %%
n = 2

# %%
2 ** 4
# Out:
# 16

# %%
import sys

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
a = np.array([5,6,7,8])

# %%
a[0], a[2]
# Out:
# (5, 7)

# %%
list1 = [1,2,3,4]

# %%
print(list1)
# Out:
# [1, 2, 3, 4]

# %%
arr_list1 = np.array(list1)

# %%
print(arr_list1)
# Out:
# [1 2 3 4]

# %%
print(type(arr_list1))
# Out:
# <class 'numpy.ndarray'>

# %%
list1 = [1,2,3,4]
list2 = [5,6,7,8]

# %%
arr_list2d = np.array([list1,list2])

# %%
print(arr_list2d)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]

# %%
print(type(arr_list2d))
# Out:
# <class 'numpy.ndarray'>

# %%
print(arr_list2d.ndim)
# Out:
# 2
